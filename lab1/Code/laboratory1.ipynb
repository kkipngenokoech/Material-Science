# %% [markdown]
# **Load LAMMPS**

# %%
# !pip install lammps

# %% [markdown]
# **Run MD Simulation**

# %%
# !lmp -in dna_charmm.in

# %% [markdown]
# **Extract Data using Linux Commands**

# %%
# !grep -A 101 "Step" log.lammps | tail -n 102 > result.dat
# !cat result.dat

# %% [markdown]
# **Import Data using Pandas Library**

# %%
import pandas as pd

# %%
result = pd.read_table('result.dat', sep='\s+')
print(result)
